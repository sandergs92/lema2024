# %%
from stable_baselines3.common import results_plotter
from stable_baselines3.common.results_plotter import load_results, ts2xy, plot_results
import matplotlib.pyplot as plt 
import numpy as np
from scipy.ndimage.filters import uniform_filter1d
# Out:
# /var/folders/k6/gg0yxj7x0tg9nllqx2xkm2rw0000gn/T/ipykernel_1925/1820901490.py:5: DeprecationWarning: Please use `uniform_filter1d` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import uniform_filter1d

# %%
log_dir = "figures/slow_model/"
timesteps = 30000
plot_results([log_dir], timesteps, results_plotter.X_TIMESTEPS, "DQN")

# %%
log_dir = "figures/slow_model/"
timesteps = 30000

# Load results
results = load_results(log_dir)
x, y = ts2xy(results, 'timesteps')

# Filter out data points beyond the specified timesteps
mask = x <= timesteps
x, y = x[mask], y[mask]

# Calculate running average
window_size = 25  # Adjust the window size for smoothing

# Initialize the running average array
y_avg = np.zeros_like(y, dtype=float)
for i in range(len(y)):
    y_avg[i] = np.mean(y[max(0, i - window_size + 1):i + 1])

# Plotting the results
plt.figure(figsize=(10, 5))
plt.scatter(x, y, alpha=0.3, label='Rewards')
plt.plot(x, y_avg, c='#1f77b4', label='Running Average', linewidth=2)
plt.xlabel('Timesteps')
plt.ylabel('Rewards')
plt.title('Training Performance of DQN')
plt.legend()
plt.show()

# %%
import re

# The input string with multiple blocks of data
s = '''
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 31.2     |
|    ep_rew_mean      | 44.6     |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 4        |
|    fps              | 1        |
|    time_elapsed     | 83       |
|    total_timesteps  | 125      |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 5.1      |
|    n_updates        | 6        |
----------------------------------
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 30.9     |
|    ep_rew_mean      | 29.5     |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 8        |
|    fps              | 1        |
|    time_elapsed     | 166      |
|    total_timesteps  | 247      |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 3.49     |
|    n_updates        | 36       |
----------------------------------
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 30.9     |
|    ep_rew_mean      | 21.2     |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 12       |
|    fps              | 1        |
|    time_elapsed     | 248      |
|    total_timesteps  | 371      |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 4.63     |
|    n_updates        | 67       |
----------------------------------
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 29.3     |
|    ep_rew_mean      | 10.1     |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 16       |
|    fps              | 1        |
|    time_elapsed     | 314      |
|    total_timesteps  | 469      |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 4.38     |
|    n_updates        | 92       |
----------------------------------
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 25.8     |
|    ep_rew_mean      | -2.1     |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 20       |
|    fps              | 1        |
|    time_elapsed     | 349      |
|    total_timesteps  | 516      |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 3.27     |
|    n_updates        | 103      |
----------------------------------
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 23       |
|    ep_rew_mean      | -22.4    |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 24       |
|    fps              | 1        |
|    time_elapsed     | 376      |
|    total_timesteps  | 552      |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 3.57     |
|    n_updates        | 112      |
----------------------------------
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 21.3     |
|    ep_rew_mean      | -25.8    |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 28       |
|    fps              | 1        |
|    time_elapsed     | 408      |
|    total_timesteps  | 597      |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 5.49     |
|    n_updates        | 124      |
----------------------------------
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 19.9     |
|    ep_rew_mean      | -26.6    |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 32       |
|    fps              | 1        |
|    time_elapsed     | 438      |
|    total_timesteps  | 638      |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 9.45     |
|    n_updates        | 134      |
----------------------------------
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 19       |
|    ep_rew_mean      | -27.5    |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 36       |
|    fps              | 1        |
|    time_elapsed     | 470      |
|    total_timesteps  | 683      |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 10.9     |
|    n_updates        | 145      |
----------------------------------
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 20.2     |
|    ep_rew_mean      | 16.9     |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 40       |
|    fps              | 1        |
|    time_elapsed     | 555      |
|    total_timesteps  | 807      |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 4
|
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 248      |
|    fps              | 0        |
|    time_elapsed     | 178      |
|    total_timesteps  | 5028     |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 5.93     |
|    n_updates        | 1231     |
----------------------------------
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 13.5     |
|    ep_rew_mean      | 0.366    |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 252      |
|    fps              | 0        |
|    time_elapsed     | 535      |
|    total_timesteps  | 5084     |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 6.3      |
|    n_updates        | 1245     |
----------------------------------
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 13.5     |
|    ep_rew_mean      | -1.57    |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 256      |
|    fps              | 0        |
|    time_elapsed     | 867      |
|    total_timesteps  | 5134     |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 7.9      |
|    n_updates        | 1258     |
----------------------------------
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 13.6     |
|    ep_rew_mean      | -1.2     |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 260      |
|    fps              | 0        |
|    time_elapsed     | 1362     |
|    total_timesteps  | 5205     |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 4.8      |
|    n_updates        | 1276     |
----------------------------------
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 13.6     |
|    ep_rew_mean      | -3.21    |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 264      |
|    fps              | 0        |
|    time_elapsed     | 1798     |
|    total_timesteps  | 5266     |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 6.66     |
|    n_updates        | 1291     |
----------------------------------
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 13.7     |
|    ep_rew_mean      | -5.24    |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 268      |
|    fps              | 0        |
|    time_elapsed     | 2216     |
|    total_timesteps  | 5324     |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 5.97     |
|    n_updates        | 1305     |
----------------------------------
----------------------------------
| rollout/            |          |
|    ep_len_mean      | 13.7     |
|    ep_rew_mean      | -1.84    |
|    exploration_rate | 0.05     |
| time/               |          |
|    episodes         | 272      |
|    fps              | 0        |
|    time_elapsed     | 2474     |
|    total_timesteps  | 5386     |
| train/              |          |
|    learning_rate    | 0.0001   |
|    loss             | 11       |
|    n_updates        | 1321     |
----------------------------------

'''

# Split the input string into a list of blocks
blocks = s.split('----------------------------------')

# Initialize an empty list to store the data
data = []

# Loop over the blocks
for block in blocks:
    # Extract the numerical values using regular expressions
    values = re.findall(r'\|\s*[a-z_]+\s*\|\s*(\d+\.?\d*)\s*\|', block)

    # If there are values in the block, convert them to floats and add them to the data list
    if values:
        values = [float(v) for v in values]
        data.append(tuple(values))

# Print the result
print(data)
# Out:
# [(31.2, 44.6, 0.05, 4.0, 1.0, 83.0, 125.0, 0.0001, 5.1, 6.0), (30.9, 29.5, 0.05, 8.0, 1.0, 166.0, 247.0, 0.0001, 3.49, 36.0), (30.9, 21.2, 0.05, 12.0, 1.0, 248.0, 371.0, 0.0001, 4.63, 67.0), (29.3, 10.1, 0.05, 16.0, 1.0, 314.0, 469.0, 0.0001, 4.38, 92.0), (25.8, 0.05, 20.0, 1.0, 349.0, 516.0, 0.0001, 3.27, 103.0), (23.0, 0.05, 24.0, 1.0, 376.0, 552.0, 0.0001, 3.57, 112.0), (21.3, 0.05, 28.0, 1.0, 408.0, 597.0, 0.0001, 5.49, 124.0), (19.9, 0.05, 32.0, 1.0, 438.0, 638.0, 0.0001, 9.45, 134.0), (19.0, 0.05, 36.0, 1.0, 470.0, 683.0, 0.0001, 10.9, 145.0), (20.2, 16.9, 0.05, 40.0, 1.0, 555.0, 807.0, 0.0001, 4.34, 176.0), (21.2, 32.6, 0.05, 44.0, 1.0, 637.0, 931.0, 0.0001, 8.3, 207.0), (21.6, 52.1, 0.05, 48.0, 1.0, 24.0, 1036.0, 0.0001, 2.62, 233.0), (21.3, 58.5, 0.05, 52.0, 1.0, 76.0, 1109.0, 0.0001, 3.58, 252.0), (22.0, 77.4, 0.05, 56.0, 1.0, 159.0, 1233.0, 0.0001, 4.57, 283.0), (22.3, 87.5, 0.05, 60.0, 1.0, 232.0, 1339.0, 0.0001, 1.96, 309.0), (22.9, 107.0, 0.05, 64.0, 1.0, 315.0, 1463.0,
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Create a DataFrame
columns = ["ep_len_mean", "ep_rew_mean", "exploration_rate", "episodes", "fps","time_elapsed", "total_timesteps", "learning_rate", "loss", "n_updates"]
df = pd.DataFrame(data, columns=columns)

# Sort the DataFrame by the 'episodes' column
df.sort_values(by='episodes', inplace=True)

# Plotting
plt.figure(figsize=(14, 6))

plt.subplot(2, 2, 1)
plt.plot(df["episodes"], df["ep_len_mean"])
plt.title("Episode Length Mean over Episodes")
plt.xlabel("Episodes")
plt.ylabel("Episode Length Mean")

plt.subplot(2, 2, 2)
plt.plot(df["episodes"], df["ep_rew_mean"])
plt.title("Episode Reward Mean over Episodes")
plt.xlabel("Episodes")
plt.ylabel("Episode Reward Mean")

plt.subplot(2, 2, 3)
plt.plot(df["episodes"], df["loss"])
plt.title("Loss over Episodes")
plt.xlabel("Episodes")
plt.ylabel("Loss")

plt.subplot(2, 2, 4)
plt.plot(df["episodes"], df["n_updates"])
plt.title("Number of Updates over Episodes")
plt.xlabel("Episodes")
plt.ylabel("Number of Updates")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from your results
model_timesteps = [1000, 2000, 3000, 4000, 5000]
avg_rewards = [237.86383819580078, 195.89943084716796, 48.354461669921875, -8.092095947265625, -66.8700927734375]
min_rewards = [163.0397720336914, 63.505043029785156, -39.832847595214844, -136, -127]
max_rewards = [285.3624572753906, 370.45249938964844, 190.71782684326172, 98.25472259521484, 70.66053771972656]

# Calculate error bars as the difference between max and min
error_min = np.array(avg_rewards) - np.array(min_rewards)
error_max = np.array(max_rewards) - np.array(avg_rewards)

# Plotting
plt.figure(figsize=(10, 6))
plt.errorbar(model_timesteps, avg_rewards, yerr=[error_min, error_max], fmt='o', capsize=5, label='Average Reward')
plt.xlabel('Timesteps')
plt.ylabel('Reward')
plt.title('Average Reward per Timestep with Min-Max Error Bars')
plt.grid(True)
plt.legend()
plt.show()

# %%
# [285.3624572753906, 234.3048858642578, 163.0397720336914, 222.72537994384766, 283.8866958618164]
# [370.45249938964844, 117.70378112792969, 241.6444320678711, 186.19139862060547, 63.505043029785156]
# [21.504318237304688, 83.93531799316406, -14.55230712890625, 190.71782684326172, -39.832847595214844]
# [98.25472259521484, -48.917137145996094, -136, 15.811531066894531, 30.390403747558594]
# [-127, 70.66053771972656, -98.85611724853516, -112, -67.1548843383789]



# Data from your results
model_timesteps = [1000, 2000, 3000, 4000, 5000]
avg_rewards = [237.86383819580078, 195.89943084716796, 48.354461669921875, -8.092095947265625, -66.8700927734375]
min_rewards = [163.0397720336914, 63.505043029785156, -39.832847595214844, -136, -127]
max_rewards = [285.3624572753906, 370.45249938964844, 190.71782684326172, 98.25472259521484, 70.66053771972656]

# Calculate error bands (shaded regions)
lower_bound = np.array(min_rewards)
upper_bound = np.array(max_rewards)

# Smooth the average rewards for a trend line
# smoothed_avg_rewards = uniform_filter1d(avg_rewards, size=3)

# Plotting
plt.figure(figsize=(10, 6))

# Plot shaded error bands
plt.fill_between(model_timesteps, lower_bound, upper_bound, alpha=0.05, color='blue', label='Min-Max Range')

# Plot trend line (smoothed average rewards)
plt.plot(model_timesteps, avg_rewards, marker='o', color='orange', label='Average Reward')
plt.xlabel('Timesteps')
plt.ylabel('Reward')
plt.title('5 trials - Average Reward per Timestep with Smoothed Trend Line and Error Bands')
plt.legend()
plt.grid(True)
plt.show()

# %%
# [30.068405151367188, 232.31881713867188, 161.3653335571289, 384.9997863769531, 399.46202087402344]
# [356.7793426513672, 308.9730224609375, 237.47936248779297, 259.1392059326172, 380.9088592529297]
# [258.37950134277344, 75.74299621582031, 362.1701126098633, 47.26927947998047, 193.50244903564453]
# [31.82306671142578, 32.99176025390625, 19.521240234375, -39.413169860839844, -121]
# [-127, -105.33106994628906, -112, -127, -49.03460693359375]



# Data from your results
model_timesteps = [1000, 2000, 3000, 4000, 5000]
avg_rewards = [241.64287261962892, 308.6559585571289, 187.4128677368164, -15.215420532226563, -104.07313537597656]
min_rewards = [30.068405151367188, 237.47936248779297, 47.26927947998047, -121, -127]
max_rewards = [399.46202087402344, 380.9088592529297, 362.1701126098633, 32.99176025390625, -49.03460693359375]

# Calculate error bands (shaded regions)
lower_bound = np.array(min_rewards)
upper_bound = np.array(max_rewards)

# Smooth the average rewards for a trend line
# smoothed_avg_rewards = uniform_filter1d(avg_rewards, size=3)

# Plotting
plt.figure(figsize=(10, 6))

# Plot shaded error bands
plt.fill_between(model_timesteps, lower_bound, upper_bound, alpha=0.05, color='blue', label='Min-Max Range')

# Plot trend line (smoothed average rewards)
plt.plot(model_timesteps, avg_rewards, marker='o', color='orange', label='Average Reward')
plt.xlabel('Timesteps')
plt.ylabel('Reward')
plt.title('5 trials - Average Reward per Timestep with Smoothed Trend Line and Error Bands')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Data from your results
model_timesteps = [1000, 2000, 3000, 4000, 5000]

# Results for model saved at 1000 timesteps
avg_rewards_1000 = 200.7736557006836
min_rewards_1000 = 14.239456176757812
max_rewards_1000 = 363.375244140625
rewards_1000 = [145.72022247314453, 212.396484375, 201.6050033569336, 14.239456176757812, 220.8493194580078, 263.04724884033203, 96.76749420166016, 363.375244140625, 226.84054565429688, 262.8955383300781]

# Results for model saved at 2000 timesteps
avg_rewards_2000 = 194.44346237182617
min_rewards_2000 = 126.49715423583984
max_rewards_2000 = 281.35302734375
rewards_2000 = [277.88902282714844, 147.11474609375, 253.96546936035156, 217.90747833251953, 142.94475555419922, 126.49715423583984, 188.09064483642578, 134.96514892578125, 281.35302734375, 173.7071762084961]

# Results for model saved at 3000 timesteps
avg_rewards_3000 = 139.2593864440918
min_rewards_3000 = 3.1090545654296875
max_rewards_3000 = 323.4874801635742
rewards_3000 = [106.63267517089844, 186.5470428466797, 204.2421646118164, 185.54395294189453, 323.4874801635742, 59.267189025878906, 3.1090545654296875, 69.48529052734375, 9.078262329101562, 245.20075225830078]

# Results for model saved at 4000 timesteps
avg_rewards_4000 = -44.19621276855469
min_rewards_4000 = -121
max_rewards_4000 = 112.76798248291016
rewards_4000 = [112.76798248291016, 66.33734130859375, -44.811492919921875, -121, -121, -121, -112, -121, 58.420127868652344, -38.67608642578125]

# Results for model saved at 5000 timesteps
avg_rewards_5000 = -32.034539794921876
min_rewards_5000 = -112
max_rewards_5000 = 86.67900848388672
rewards_5000 = [7.7444305419921875, -104.85041809082031, -101.84748840332031, -22.42919158935547, -112, 20.636184692382812, 86.67900848388672, 36.434715270996094, -105.83480072021484, -24.877838134765625]

# Calculate error bands (shaded regions)
lower_bound = np.array([min_rewards_1000, min_rewards_2000, min_rewards_3000, min_rewards_4000, min_rewards_5000])
upper_bound = np.array([max_rewards_1000, max_rewards_2000, max_rewards_3000, max_rewards_4000, max_rewards_5000])

# Smoothed average rewards for trend lines
# smoothed_avg_rewards = uniform_filter1d([avg_rewards_1000, avg_rewards_2000, avg_rewards_3000, avg_rewards_4000, avg_rewards_5000], size=3)

avg_rewards = [avg_rewards_1000, avg_rewards_2000, avg_rewards_3000, avg_rewards_4000, avg_rewards_5000]

# Plotting
plt.figure(figsize=(10, 6))

# Plot shaded error bands
plt.fill_between(model_timesteps, lower_bound, upper_bound, alpha=0.05, color='blue', label='Min-Max Range')

# Plot trend line (smoothed average rewards)
plt.plot(model_timesteps, avg_rewards, marker='o', color='orange', label='Average Reward')

plt.xlabel('Timesteps')
plt.ylabel('Reward')
plt.title('10 trials - Average Reward per Timestep with Smoothed Trend Line and Error Bands')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Data from your results
model_timesteps = [1000, 2000, 3000, 4000, 5000]

# Results for model saved at 1000 timesteps
avg_rewards_1000 = 231.61374267578125
min_rewards_1000 = 7.7597198486328125
max_rewards_1000 = 403.19861602783203
rewards_1000 = [340.4981994628906, 117.97158813476562, 275.03956604003906, 173.80044555664062, 390.62864685058594, 393.43885803222656, 105.93222045898438, 154.91768646240234, 331.1762924194336, 24.72234344482422, 7.7597198486328125, 112.7486801147461, 220.17625427246094, 161.21316528320312, 403.19861602783203, 191.60581970214844, 327.9606628417969, 349.5992736816406, 167.96304321289062, 325.1124267578125, 308.5009994506836, 268.0347366333008, 228.4166717529297, 87.14592742919922, 322.78172302246094]

# Results for model saved at 2000 timesteps
avg_rewards_2000 = 204.9900341796875
min_rewards_2000 = -13.888984680175781
max_rewards_2000 = 430.82068634033203
rewards_2000 = [46.717063903808594, 294.78282165527344, 251.3987045288086, 129.68390655517578, 277.3575210571289, 430.82068634033203, 385.2124557495117, 322.9543228149414, 135.63936614990234, 269.77954864501953, 228.6512451171875, 294.2600784301758, 380.92384338378906, 363.7842788696289, 38.661354064941406, 103.1777572631836, 281.1100845336914, 254.49739837646484, 114.5144271850586, 180.7743682861328, 125.2125244140625, 61.282470703125, 62.13197326660156, -13.888984680175781, 105.31163787841797]

# Results for model saved at 3000 timesteps
avg_rewards_3000 = 133.14577758789062
min_rewards_3000 = -29.903793334960938
max_rewards_3000 = 410.79549407958984
rewards_3000 = [142.11373901367188, 68.7464599609375, 157.2180633544922, 246.12413787841797, -8.629890441894531, 34.878814697265625, 46.190269470214844, -29.903793334960938, 42.73217010498047, 314.7606735229492, 63.91912078857422, -26.89067840576172, 266.55755615234375, 136.09114837646484, 101.07634735107422, 213.12648010253906, 410.79549407958984, 314.0117645263672, 38.06102752685547, 274.9234085083008, 148.2790069580078, 56.34278869628906, 117.95663452148438, 54.047325134277344, 146.11637115478516]

# Results for model saved at 4000 timesteps
avg_rewards_4000 = -36.07461395263672
min_rewards_4000 = -136
max_rewards_4000 = 142.48287963867188
rewards_4000 = [-44.98944854736328, -20.12610626220703, -35.322357177734375, 6.4613800048828125, 76.20096588134766, -108.41287231445312, -97.53756713867188, 116.83275604248047, 67.04630279541016, -46.2374267578125, -112, -136, -127, -105.01197052001953, -121, 3.68145751953125, -35.12940979003906, 1.550262451171875, -104.84832000732422, 52.111671447753906, -55.983863830566406, -130.8456268310547, 24.211944580078125, -112, 142.48287963867188]

# Results for model saved at 5000 timesteps
avg_rewards_5000 = -20.901699829101563
min_rewards_5000 = -127
max_rewards_5000 = 129.60379028320312
rewards_5000 = [-105.68659973144531, 17.930404663085938, -127, -127, -105.72875213623047, 16.397872924804688, -38.11427307128906, 31.399253845214844, -23.01061248779297, 2.9410247802734375, 10.995048522949219, 129.60379028320312, 72.81029510498047, 78.37326049804688, -38.610870361328125, -121, 3.8441238403320312, 13.238494873046875, -24.71759033203125, -4.667022705078125, -37.03785705566406, 41.29780578613281, -39.27056121826172, -104.93815612792969, -44.591575622558594]

# Calculate error bands (shaded regions)
lower_bound = np.array([min_rewards_1000, min_rewards_2000, min_rewards_3000, min_rewards_4000, min_rewards_5000])
upper_bound = np.array([max_rewards_1000, max_rewards_2000, max_rewards_3000, max_rewards_4000, max_rewards_5000])

# Smoothed average rewards for trend lines
smoothed_avg_rewards = [avg_rewards_1000, avg_rewards_2000, avg_rewards_3000, avg_rewards_4000, avg_rewards_5000]

# Plotting
plt.figure(figsize=(10, 6))

# Plot shaded error bands
plt.fill_between(model_timesteps, lower_bound, upper_bound, alpha=0.1, color='blue', label='Min-Max Range')

# Plot trend line (smoothed average rewards)
plt.plot(model_timesteps, smoothed_avg_rewards, marker='o', color='orange', label='Average Reward')

plt.xlabel('Timesteps')
plt.ylabel('Reward')
plt.title('25 trials - Average Reward per Timestep with Min-Max Error Bands')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Data from your results
model_timesteps = [1000, 2000, 3000, 4000, 5000]

# Results for model saved at 1000 timesteps
avg_rewards_1000 = 200.7736557006836
min_rewards_1000 = 14.239456176757812
max_rewards_1000 = 363.375244140625
rewards_1000 = [145.72022247314453, 212.396484375, 201.6050033569336, 14.239456176757812, 220.8493194580078, 263.04724884033203, 96.76749420166016, 363.375244140625, 226.84054565429688, 262.8955383300781]

# Results for model saved at 2000 timesteps
avg_rewards_2000 = 194.44346237182617
min_rewards_2000 = 126.49715423583984
max_rewards_2000 = 281.35302734375
rewards_2000 = [277.88902282714844, 147.11474609375, 253.96546936035156, 217.90747833251953, 142.94475555419922, 126.49715423583984, 188.09064483642578, 134.96514892578125, 281.35302734375, 173.7071762084961]

# Results for model saved at 3000 timesteps
avg_rewards_3000 = 139.2593864440918
min_rewards_3000 = 3.1090545654296875
max_rewards_3000 = 323.4874801635742
rewards_3000 = [106.63267517089844, 186.5470428466797, 204.2421646118164, 185.54395294189453, 323.4874801635742, 59.267189025878906, 3.1090545654296875, 69.48529052734375, 9.078262329101562, 245.20075225830078]

# Results for model saved at 4000 timesteps
avg_rewards_4000 = -44.19621276855469
min_rewards_4000 = -121
max_rewards_4000 = 112.76798248291016
rewards_4000 = [112.76798248291016, 66.33734130859375, -44.811492919921875, -121, -121, -121, -112, -121, 58.420127868652344, -38.67608642578125]

# Results for model saved at 5000 timesteps
avg_rewards_5000 = -32.034539794921876
min_rewards_5000 = -112
max_rewards_5000 = 86.67900848388672
rewards_5000 = [7.7444305419921875, -104.85041809082031, -101.84748840332031, -22.42919158935547, -112, 20.636184692382812, 86.67900848388672, 36.434715270996094, -105.83480072021484, -24.877838134765625]

# Smoothed average rewards for trend lines
# smoothed_avg_rewards = uniform_filter1d([avg_rewards_1000, avg_rewards_2000, avg_rewards_3000, avg_rewards_4000, avg_rewards_5000], size=3)

avg_rewards = [avg_rewards_1000, avg_rewards_2000, avg_rewards_3000, avg_rewards_4000, avg_rewards_5000]

# Plotting
plt.figure(figsize=(10, 5))  # Adjusted figure size to match the second plot

# Scatter plot for the results from the second graph
log_dir = "figures/slow_model/"
timesteps = 30000

# Load results
results = load_results(log_dir)
x, y = ts2xy(results, 'timesteps')

# Filter out data points beyond the specified timesteps
mask = x <= timesteps
x, y = x[mask], y[mask]

# Calculate running average
window_size = 25  # Adjust the window size for smoothing

# Initialize the running average array
y_avg = np.zeros_like(y, dtype=float)
for i in range(len(y)):
    y_avg[i] = np.mean(y[max(0, i - window_size + 1):i + 1])

# Plotting the results from the second graph
plt.scatter(x, y, alpha=0.3, label='Training Rewards')
plt.plot(x, y_avg, c='#1f77b4', label='Average Training Reward', linewidth=2)

# Plot trend line (smoothed average rewards) from the first graph
plt.plot(model_timesteps, avg_rewards, marker='o', color='orange', label='Average Validation Reward')

plt.xlabel('Timesteps')
plt.ylabel('Reward')
plt.title('Combined Training Performance Comparison')
plt.grid(True)
plt.legend()
plt.xlim(0, 5500)  # Set x-axis limits to match the second plot
plt.ylim(-200, 500)  # Set y-axis limits to match the second plot
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %%
# Data from your results
model_timesteps = [1000, 2000, 3000, 4000, 5000]

# Results for model saved at 1000 timesteps
avg_rewards_1000 = 231.61374267578125
min_rewards_1000 = 7.7597198486328125
max_rewards_1000 = 403.19861602783203
rewards_1000 = [340.4981994628906, 117.97158813476562, 275.03956604003906, 173.80044555664062, 390.62864685058594, 393.43885803222656, 105.93222045898438, 154.91768646240234, 331.1762924194336, 24.72234344482422, 7.7597198486328125, 112.7486801147461, 220.17625427246094, 161.21316528320312, 403.19861602783203, 191.60581970214844, 327.9606628417969, 349.5992736816406, 167.96304321289062, 325.1124267578125, 308.5009994506836, 268.0347366333008, 228.4166717529297, 87.14592742919922, 322.78172302246094]

# Results for model saved at 2000 timesteps
avg_rewards_2000 = 204.9900341796875
min_rewards_2000 = -13.888984680175781
max_rewards_2000 = 430.82068634033203
rewards_2000 = [46.717063903808594, 294.78282165527344, 251.3987045288086, 129.68390655517578, 277.3575210571289, 430.82068634033203, 385.2124557495117, 322.9543228149414, 135.63936614990234, 269.77954864501953, 228.6512451171875, 294.2600784301758, 380.92384338378906, 363.7842788696289, 38.661354064941406, 103.1777572631836, 281.1100845336914, 254.49739837646484, 114.5144271850586, 180.7743682861328, 125.2125244140625, 61.282470703125, 62.13197326660156, -13.888984680175781, 105.31163787841797]

# Results for model saved at 3000 timesteps
avg_rewards_3000 = 133.14577758789062
min_rewards_3000 = -29.903793334960938
max_rewards_3000 = 410.79549407958984
rewards_3000 = [142.11373901367188, 68.7464599609375, 157.2180633544922, 246.12413787841797, -8.629890441894531, 34.878814697265625, 46.190269470214844, -29.903793334960938, 42.73217010498047, 314.7606735229492, 63.91912078857422, -26.89067840576172, 266.55755615234375, 136.09114837646484, 101.07634735107422, 213.12648010253906, 410.79549407958984, 314.0117645263672, 38.06102752685547, 274.9234085083008, 148.2790069580078, 56.34278869628906, 117.95663452148438, 54.047325134277344, 146.11637115478516]

# Results for model saved at 4000 timesteps
avg_rewards_4000 = -36.07461395263672
min_rewards_4000 = -136
max_rewards_4000 = 142.48287963867188
rewards_4000 = [-44.98944854736328, -20.12610626220703, -35.322357177734375, 6.4613800048828125, 76.20096588134766, -108.41287231445312, -97.53756713867188, 116.83275604248047, 67.04630279541016, -46.2374267578125, -112, -136, -127, -105.01197052001953, -121, 3.68145751953125, -35.12940979003906, 1.550262451171875, -104.84832000732422, 52.111671447753906, -55.983863830566406, -130.8456268310547, 24.211944580078125, -112, 142.48287963867188]

# Results for model saved at 5000 timesteps
avg_rewards_5000 = -20.901699829101563
min_rewards_5000 = -127
max_rewards_5000 = 129.60379028320312
rewards_5000 = [-105.68659973144531, 17.930404663085938, -127, -127, -105.72875213623047, 16.397872924804688, -38.11427307128906, 31.399253845214844, -23.01061248779297, 2.9410247802734375, 10.995048522949219, 129.60379028320312, 72.81029510498047, 78.37326049804688, -38.610870361328125, -121, 3.8441238403320312, 13.238494873046875, -24.71759033203125, -4.667022705078125, -37.03785705566406, 41.29780578613281, -39.27056121826172, -104.93815612792969, -44.591575622558594]

avg_rewards = [avg_rewards_1000, avg_rewards_2000, avg_rewards_3000, avg_rewards_4000, avg_rewards_5000]

# Error bars for validation rewards (min and max)
lower_error = [avg_rewards_1000 - min_rewards_1000, avg_rewards_2000 - min_rewards_2000, avg_rewards_3000 - min_rewards_3000, avg_rewards_4000 - min_rewards_4000, avg_rewards_5000 - min_rewards_5000]
upper_error = [max_rewards_1000 - avg_rewards_1000, max_rewards_2000 - avg_rewards_2000, max_rewards_3000 - avg_rewards_3000, max_rewards_4000 - avg_rewards_4000, max_rewards_5000 - avg_rewards_5000]


# Plotting
plt.figure(figsize=(10, 5))  # Adjusted figure size to match the second plot

# Scatter plot for the results from the second graph
log_dir = "figures/slow_model/"
timesteps = 30000

# Load results
results = load_results(log_dir)
x, y = ts2xy(results, 'timesteps')

# Filter out data points beyond the specified timesteps
mask = x <= timesteps
x, y = x[mask], y[mask]

# Calculate running average
window_size = 25  # Adjust the window size for smoothing

# Initialize the running average array
y_avg = np.zeros_like(y, dtype=float)
for i in range(len(y)):
    y_avg[i] = np.mean(y[max(0, i - window_size + 1):i + 1])

# Plotting the results from the second graph
plt.scatter(x, y, alpha=0.3, label='Training Rewards')
plt.plot(x, y_avg, c='#1f77b4', label='Average Training Reward', linewidth=2)

# Plot trend line (smoothed average rewards) from the first graph
plt.plot(model_timesteps, avg_rewards, marker='o', color='orange', label='Average Validation Reward')

# Plot trend line (smoothed average rewards) from the first graph (validation)
plt.errorbar(model_timesteps, smoothed_avg_rewards, yerr=[lower_error, upper_error], fmt='o', capsize=5, color='orange', label='Max and Min Validation Reward')

plt.xlabel('Timesteps')
plt.ylabel('Reward')
plt.title('Combined Training Performance Comparison')
plt.grid(True)
plt.legend()
plt.xlim(0, 5500)  # Set x-axis limits to match the second plot
plt.ylim(-200, 500)  # Set y-axis limits to match the second plot
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %%
# Data from your results
model_timesteps = [1000, 2000, 3000, 4000, 5000]

# Results for model saved at 1000 timesteps
avg_rewards_1000 = 231.61374267578125
rewards_1000 = [340.4981994628906, 117.97158813476562, 275.03956604003906, 173.80044555664062, 390.62864685058594, 393.43885803222656, 105.93222045898438, 154.91768646240234, 331.1762924194336, 24.72234344482422, 7.7597198486328125, 112.7486801147461, 220.17625427246094, 161.21316528320312, 403.19861602783203, 191.60581970214844, 327.9606628417969, 349.5992736816406, 167.96304321289062, 325.1124267578125, 308.5009994506836, 268.0347366333008, 228.4166717529297, 87.14592742919922, 322.78172302246094]

# Results for model saved at 2000 timesteps
avg_rewards_2000 = 204.9900341796875
rewards_2000 = [46.717063903808594, 294.78282165527344, 251.3987045288086, 129.68390655517578, 277.3575210571289, 430.82068634033203, 385.2124557495117, 322.9543228149414, 135.63936614990234, 269.77954864501953, 228.6512451171875, 294.2600784301758, 380.92384338378906, 363.7842788696289, 38.661354064941406, 103.1777572631836, 281.1100845336914, 254.49739837646484, 114.5144271850586, 180.7743682861328, 125.2125244140625, 61.282470703125, 62.13197326660156, -13.888984680175781, 105.31163787841797]

# Results for model saved at 3000 timesteps
avg_rewards_3000 = 133.14577758789062
rewards_3000 = [142.11373901367188, 68.7464599609375, 157.2180633544922, 246.12413787841797, -8.629890441894531, 34.878814697265625, 46.190269470214844, -29.903793334960938, 42.73217010498047, 314.7606735229492, 63.91912078857422, -26.89067840576172, 266.55755615234375, 136.09114837646484, 101.07634735107422, 213.12648010253906, 410.79549407958984, 314.0117645263672, 38.06102752685547, 274.9234085083008, 148.2790069580078, 56.34278869628906, 117.95663452148438, 54.047325134277344, 146.11637115478516]

# Results for model saved at 4000 timesteps
avg_rewards_4000 = -36.07461395263672
rewards_4000 = [-44.98944854736328, -20.12610626220703, -35.322357177734375, 6.4613800048828125, 76.20096588134766, -108.41287231445312, -97.53756713867188, 116.83275604248047, 67.04630279541016, -46.2374267578125, -112, -136, -127, -105.01197052001953, -121, 3.68145751953125, -35.12940979003906, 1.550262451171875, -104.84832000732422, 52.111671447753906, -55.983863830566406, -130.8456268310547, 24.211944580078125, -112, 142.48287963867188]

# Results for model saved at 5000 timesteps
avg_rewards_5000 = -20.901699829101563
rewards_5000 = [-105.68659973144531, 17.930404663085938, -127, -127, -105.72875213623047, 16.397872924804688, -38.11427307128906, 31.399253845214844, -23.01061248779297, 2.9410247802734375, 10.995048522949219, 129.60379028320312, 72.81029510498047, 78.37326049804688, -38.610870361328125, -121, 3.8441238403320312, 13.238494873046875, -24.71759033203125, -4.667022705078125, -37.03785705566406, 41.29780578613281, -39.27056121826172, -104.93815612792969, -44.591575622558594]

avg_rewards = [avg_rewards_1000, avg_rewards_2000, avg_rewards_3000, avg_rewards_4000, avg_rewards_5000]

# Calculate the standard deviation for each reward set
std_rewards_1000 = np.std(rewards_1000)
std_rewards_2000 = np.std(rewards_2000)
std_rewards_3000 = np.std(rewards_3000)
std_rewards_4000 = np.std(rewards_4000)
std_rewards_5000 = np.std(rewards_5000)

# Standard deviations
std_rewards = [std_rewards_1000, std_rewards_2000, std_rewards_3000, std_rewards_4000, std_rewards_5000]

# Calculate episodes (every 1000 timesteps is 1 episode)
episodes = np.arange(1, len(model_timesteps) + 1)

# Plotting
plt.figure(figsize=(8, 5))

# Scatter plot for the results from the second graph
log_dir = "figures/slow_model/"
timesteps = 30000

# Load results
results = load_results(log_dir)
x, y = ts2xy(results, 'timesteps')

# Filter out data points beyond the specified timesteps
mask = x <= timesteps
x, y = x[mask], y[mask]

# Calculate running average
window_size = 25  # Adjust the window size for smoothing

# Initialize the running average array
y_avg = np.zeros_like(y, dtype=float)
for i in range(len(y)):
    y_avg[i] = np.mean(y[max(0, i - window_size + 1):i + 1])

# Plotting the results from the second graph
plt.scatter(x, y, alpha=0.3, label='Training Rewards')
plt.plot(x, y_avg, c='#1f77b4', label='Average Training Reward', linewidth=2)

# # Plot trend line (smoothed average rewards) from the first graph
# plt.plot(model_timesteps, avg_rewards, marker='o', color='orange', label='Average Validation Reward')

# # Plot error bars using standard deviations
# plt.errorbar(model_timesteps, avg_rewards, yerr=std_rewards, fmt='o', capsize=5, color='orange', label='Validation Reward Std Dev')
plt.errorbar(model_timesteps, avg_rewards, yerr=std_rewards, fmt='o-', capsize=5, color='orange', label='Average Validation Score')

plt.xlabel('Timesteps')
plt.ylabel('Reward')
plt.title('Combined Training Performance Comparison')
plt.grid(True)
plt.legend()

# Secondary x-axis for episodes
plt.twiny()
plt.xlabel('Episodes')
plt.xticks(model_timesteps, episodes)

plt.xlim(0, 5500)  # Set x-axis limits to match the second plot
plt.ylim(-200, 500)  # Set y-axis limits to match the second plot
plt.tight_layout()  # Adjust layout to prevent overlapping labels

plt.savefig('T2_training_validation.pdf', bbox_inches='tight')

plt.show()

# %%
# Data
timesteps = np.array([1, 2, 3, 4, 5])
avg_food_eaten = [3.68, 3.4, 2.64, 1.12, 1.16]
avg_steps_per_food = [6.7280000000000015, 6.047809523809524, 7.97, 3.3200000000000007, 4.06]

# low number - 3.32 is because it collides with all and therefore overall average steps to food is higher because it collects 1 or 2 before colliding with the wall

# Bar width
width = 0.35

# Create subplots
fig, ax1 = plt.subplots(figsize=(7, 5))

# Bar graph for average food eaten
bar1 = ax1.bar(timesteps - width/2, avg_food_eaten, width, color='#1f77b4', label='Avg Food Eaten')
ax1.set_xlabel('Timesteps')
ax1.set_ylabel('Food Eaten and Steps per Food')
# ax1.tick_params(axis='y')
ax1.set_ylim(0, max(avg_steps_per_food) + 1)

# Adding a second y-axis for average steps per food
# ax2 = ax1.twinx()
bar2 = ax1.bar(timesteps + width/2, avg_steps_per_food, width, color='orange', label='Avg Steps per Food')
# ax2.set_ylabel('Average Steps per Food and Steps per Food')
# ax2.tick_params(axis='y')
# ax2.set_ylim(0, max(avg_steps_per_food) + 1)

# Adding title and grid
plt.title('Average Food Eaten and Steps per Food over Timesteps')
ax1.grid(True)
fig.tight_layout()

# Adding legends
bars = [bar1, bar2]
labels = [bar.get_label() for bar in bars]
ax1.legend(bars, labels, loc='upper right')

# plt.savefig('T2_food_eaten.pdf', bbox_inches='tight')

# Display the plot
plt.show()
